# %% [markdown]
# # Week 3 Exercise: Multiple Regression, Vectorization, Feature Scaling, and Feature Engineering
#
# This lab covers the Week 3 material from **Introduction to Multiple Features** through **Choosing Features for Regression**.
#
# ### Learning outcomes
# By the end of the practical, you should be able to:
#
# 1. Represent multiple features using vectors and matrices.
# 2. Implement vectorized multiple-linear-regression predictions.
# 3. Compute the cost and gradients for multiple regression.
# 4. Train a model using Batch Gradient Descent.
# 5. Compare gradient descent with a closed-form least-squares solution.
# 6. Apply and compare feature-scaling methods.
# 7. Diagnose convergence and learning-rate problems.
# 8. Engineer new features from existing variables.
# 9. Create polynomial and transformed features.
# 10. Compare feature sets using validation performance.
# 11. Justify a final feature choice for a regression model.
#
# ## Dataset
# Use the accompanying file **`week3_multiple_regression_housing.csv`**.
#
# | Column | Meaning |
# |---|---|
# | `house_id` | Unique house identifier |
# | `size_sqft` | Interior size in square feet |
# | `bedrooms` | Number of bedrooms |
# | `age_years` | Age of house |
# | `frontage_ft` | Lot frontage |
# | `depth_ft` | Lot depth |
# | `distance_city_km` | Distance from city center |
# | `price_ugx` | Sale price (target) |

# %% [markdown]
# ## Setup
# Run this cell first. We will use NumPy, pandas, and Matplotlib.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.set_printoptions(suppress=True, precision=4)
DATA_FILE = "week3_multiple_regression_housing.csv"
print("Environment ready.")

# %% [markdown]
# # 1. Introduction to Multiple Features
#
# Multiple linear regression predicts one continuous target using several predictors:
#
# $\hat y=w_1x_1+w_2x_2+\cdots+w_nx_n+b$
#
# This is **multiple linear regression** because there are multiple independent variables but a single dependent variable.
#
# ### TODO 1 — Load and inspect the dataset
#
# **Instructions**
# 1. Read the CSV into a DataFrame named `df`.
# 2. Display the first 10 rows.
# 3. Print the shape, column names, data types, and missing-value counts.
# 4. Use `describe()` for the numerical columns.
# 5. Identify the target and at least five candidate predictors.
# 6. In a Markdown cell, explain why this is multiple linear regression rather than multivariate regression.

# %%
# TODO 1
# df = pd.read_csv(DATA_FILE)
# ...

# %% [markdown]
# # 2. Feature Representation in Data
#
# For one example, the feature vector is
# $\mathbf{x}=[x_1,x_2,\ldots,x_n]^T$
# and for all examples the feature matrix is \($X\in\mathbb{R}^{m\times n}$\).
#
# ### TODO 2 — Build the feature matrix
#
# Use `size_sqft`, `bedrooms`, `age_years`, and `distance_city_km`.
#
# **Instructions**
# 1. Store these names in `base_features`.
# 2. Create NumPy arrays `X` and `y`.
# 3. Print their shapes.
# 4. Print the first feature vector.
# 5. Explain what the two dimensions of `X.shape` represent.

# %%
# TODO 2
base_features = ["size_sqft", "bedrooms", "age_years", "distance_city_km"]
# X = ...
# y = ...
# ...

# %% [markdown]
# # 3. Model for Multiple Variables
#
# The model can be written compactly as:
# $f_{\mathbf w,b}(\mathbf x)=\mathbf w^T\mathbf x+b$
#
# ### TODO 3 — Implement one prediction
#
# **Instructions**
# 1. Write `predict_one(x, w, b)` using a dot product.
# 2. Test it on the first house with a weight vector of the correct length.
# 3. Recompute the same prediction manually with a loop.
# 4. Verify the two answers match.

# %%
# TODO 3
def predict_one(x, w, b):
    raise NotImplementedError("Complete TODO 3")

# %% [markdown]
# # 4. Vectorization Part 1
#
# For all examples at once:
# $\hat{\mathbf y}=X\mathbf w+b$
#
# ### TODO 4 — Loop vs. vectorized prediction
#
# **Instructions**
# 1. Write `predict_loop(X,w,b)` with explicit loops.
# 2. Write `predict_vectorized(X,w,b)` with matrix multiplication.
# 3. Compare outputs with `np.allclose()`.
# 4. Print the first five predictions.
# 5. Explain why vectorization is preferred for large datasets.

# %%
# TODO 4
def predict_loop(X, w, b):
    raise NotImplementedError

def predict_vectorized(X, w, b):
    raise NotImplementedError

# %% [markdown]
# # 5. Vectorization Part 2: Dimensions and Dot Products
#
# Matrix multiplication is only valid when dimensions align.
#
# ### TODO 5 — Trace dimensions
#
# **Instructions**
# 1. Print the shapes of `X`, `w`, `X @ w`, and the final prediction vector.
# 2. Explain why `X @ w` is valid.
# 3. Create an incorrectly sized weight vector and intentionally run `X @ w_wrong`.
# 4. Interpret the error message in your own words.

# %%
# TODO 5
# print(X.shape)
# w = ...
# w_wrong = ...

# %% [markdown]
# # 6. Cost Function for Multiple Regression
#
# Use the squared-error cost:
# $J(\mathbf w,b)=\frac{1}{2m}\sum_{i=1}^{m}(\hat y^{(i)}-y^{(i)})^2$
#
# ### TODO 6 — Implement vectorized cost
#
# **Instructions**
# 1. Write `compute_cost_multi(X,y,w,b)`.
# 2. Use vectorized predictions and residuals.
# 3. Return a single scalar.
# 4. Evaluate the cost for zero parameters and one nonzero parameter set.
# 5. Explain why the cost is one number despite multiple model parameters.

# %%
# TODO 6
def compute_cost_multi(X, y, w, b):
    raise NotImplementedError("Complete TODO 6")

# %% [markdown]
# # 7. Gradients for Multiple Regression
#
# The vectorized weight gradient is
# $\nabla_{\mathbf w}J=\frac{1}{m}X^T(\hat{\mathbf y}-\mathbf y)$
# and
# $\frac{\partial J}{\partial b}=\frac{1}{m}\sum_i(\hat y^{(i)}-y^{(i)})$.
#
# ### TODO 7 — Implement gradients
#
# **Instructions**
# 1. Write `compute_gradient_multi(X,y,w,b)` returning `dj_dw, dj_db`.
# 2. Confirm `dj_dw.shape == w.shape`.
# 3. Test at two parameter settings.
# 4. Explain what gradients near zero suggest.

# %%
# TODO 7
def compute_gradient_multi(X, y, w, b):
    raise NotImplementedError("Complete TODO 7")

# %% [markdown]
# # 8. Gradient Descent for Multiple Regression
#
# Gradient descent updates all parameters simultaneously:
# $\mathbf w\leftarrow\mathbf w-\alpha\nabla_{\mathbf w}J,\quad b\leftarrow b-\alpha\frac{\partial J}{\partial b}$
#
# ### TODO 8 — Implement Batch Gradient Descent
#
# **Instructions**
# 1. Write a function accepting `X`, `y`, initial parameters, learning rate, and iterations.
# 2. Use **all training examples** for every gradient calculation.
# 3. Update all weights simultaneously.
# 4. Record cost history and optionally parameter history.
# 5. Stop if cost becomes non-finite.
# 6. Return final parameters and histories.

# %%
# TODO 8
def batch_gradient_descent_multi(X, y, w_init, b_init, alpha, num_iterations):
    raise NotImplementedError("Complete TODO 8")

# %% [markdown]
# # 9. Feature Scaling: Why It Matters
#
# Features can have very different numerical scales. Scaling improves optimization conditioning; it does **not** make every feature equally important.
#
# ### TODO 9 — Inspect feature scales
#
# **Instructions**
# 1. For every base feature, calculate min, max, mean, std, and range.
# 2. Put the results in a DataFrame.
# 3. Identify the largest and smallest numerical ranges.
# 4. Explain why one global learning rate can be difficult to choose when scales differ greatly.

# %%
# TODO 9
# Build a scale-summary DataFrame
# ...

# %% [markdown]
# # 10. Feature Scaling Methods
#
# Implement and compare:
#
# - Min-max scaling: \($(x-x_{min})/(x_{max}-x_{min})$\)
# - Mean normalization: \($(x-\mu)/(x_{max}-x_{min})$\)
# - Z-score standardization: \($(x-\mu)/\sigma$\)
#
# ### TODO 10 — Implement the three methods
#
# **Instructions**
# 1. Write one function for each method.
# 2. Apply them to `size_sqft`.
# 3. Report min, max, mean, and std after transformation.
# 4. Visualize the transformed values.
# 5. State which method guarantees a 0–1 interval and which uses standard deviation.

# %%
# TODO 10
def min_max_scale(x):
    raise NotImplementedError

def mean_normalize(x):
    raise NotImplementedError

def z_score_scale(x):
    raise NotImplementedError

# %% [markdown]
# # 11. Feature Size and Gradient Descent
#
# Unscaled features often create elongated cost contours, causing inefficient zig-zag updates. Balanced scales usually produce smoother convergence.
#
# ### TODO 11 — Compare raw vs. standardized training
#
# **Instructions**
# 1. Create `X_raw` from the base features.
# 2. Standardize each column to produce `X_scaled`.
# 3. Train the same BGD model on both.
# 4. Tune learning rates independently if needed.
# 5. Plot both cost histories.
# 6. Compare stability and convergence speed.
# 7. Explain why learned weight magnitudes are not directly comparable across the two representations.

# %%
# TODO 11
# X_raw = ...
# X_scaled = ...
# ...

# %% [markdown]
# # 12. Checking Gradient Descent Convergence
#
# A well-behaved learning curve decreases and eventually flattens.
#
# ### TODO 12 — Add an automatic convergence rule
#
# **Instructions**
# 1. Use a rule such as `abs($J_t - J_t_minus_1$) < $epsilon$`.
# 2. Require the condition for several consecutive iterations before stopping.
# 3. Record the convergence iteration.
# 4. Plot the learning curve and mark the convergence point.
# 5. Explain why one small cost change alone may be misleading.

# %%
# TODO 12
# Add epsilon-based early stopping to your gradient descent function.

# %% [markdown]
# # 13. Choosing the Learning Rate
#
# A learning rate that is too large can oscillate or diverge; one that is too small converges slowly.
#
# ### TODO 13 — Learning-rate experiment
#
# **Instructions**
# 1. Using scaled features, test at least five learning rates such as `1e-4`, `1e-3`, `1e-2`, `1e-1`, and `1.0`.
# 2. Start every run from identical parameters.
# 3. Plot all cost histories together.
# 4. Label each rate as too small, useful, or too large.
# 5. Preserve divergent runs in your analysis rather than silently removing them.

# %%
# TODO 13
learning_rates = [1e-4, 1e-3, 1e-2, 1e-1, 1.0]
# ...

# %% [markdown]
# # 14. Alternative to Gradient Descent: Normal Equation
#
# For ordinary least squares, a closed-form solution can be obtained from a design matrix with an intercept column. In practice, use numerically stable solvers rather than explicit inversion.
#
# ### TODO 14 — Solve with least squares
#
# **Instructions**
# 1. Build a design matrix containing a leading column of ones and the base features.
# 2. Solve using `np.linalg.lstsq()` or `np.linalg.pinv()`.
# 3. Extract the intercept and feature weights.
# 4. Compute training predictions and cost.
# 5. Compare the answer with BGD.
# 6. Explain why no learning rate is needed and why gradient-based optimization remains important for large models.

# %%
# TODO 14
# X_design = ...
# theta = np.linalg.lstsq(...)[0]
# ...

# %% [markdown]
# # 15. Feature Engineering
#
# Feature engineering creates useful new variables from existing information. Here a natural example is lot area:
# $\text{lot area}=\text{frontage}\times\text{depth}$
#
# ### TODO 15 — Engineer `lot_area_sqft`
#
# **Instructions**
# 1. Create `df["lot_area_sqft"]`.
# 2. Summarize it statistically.
# 3. Plot lot area against price.
# 4. Compute its correlation with price.
# 5. Compare a model with and without this feature using validation data.
# 6. State whether the engineered feature improved generalization.

# %%
# TODO 15
# df["lot_area_sqft"] = ...
# ...

# %% [markdown]
# # 16. Polynomial Regression and Transformed Features
#
# Polynomial regression is nonlinear in the input but linear in the learned parameters. Useful transformed features include \($x^2$\), \($x^3$\), and \($\sqrt{x}$\).
#
# ### TODO 16 — Create transformed size features
#
# **Instructions**
# 1. Add `size_sqft_squared = size_sqft ** 2`.
# 2. Add `sqrt_size_sqft = np.sqrt(size_sqft)`.
# 3. Build at least three models: size only; size + size²; size + sqrt(size).
# 4. Scale appropriately.
# 5. Compare validation error.
# 6. Explain why adding transformations can improve fit but also increase overfitting risk.

# %%
# TODO 16
# df["size_sqft_squared"] = ...
# df["sqrt_size_sqft"] = ...

# %% [markdown]
# # 17. Create a Train/Validation Split
#
# Feature choices should be judged on data not used to fit the model.
#
# ### TODO 17 — Build an 80/20 split
#
# **Instructions**
# 1. Shuffle indices with a fixed random seed.
# 2. Allocate about 80% to training and 20% to validation.
# 3. Create `train_df` and `val_df`.
# 4. Verify there is no overlap.
# 5. Explain why training error alone is not a reliable criterion for choosing features.

# %%
# TODO 17
rng = np.random.default_rng(42)
# indices = ...
# ...

# %% [markdown]
# # 18. Choosing Features for Regression
#
# Feature selection should balance relevance, redundancy, complexity, and validation performance.
#
# ### TODO 18 — Compare candidate feature sets
#
# Evaluate these models:
#
# - **A:** `size_sqft`
# - **B:** `size_sqft`, `bedrooms`, `age_years`, `distance_city_km`
# - **C:** B + `lot_area_sqft`
# - **D:** C + `sqrt_size_sqft`
# - **E:** D + `size_sqft_squared`
#
# **Instructions**
# 1. Fit scaling statistics using training data **only**.
# 2. Apply those same statistics to validation data.
# 3. Fit each model using BGD or least squares.
# 4. Record training MSE and validation MSE.
# 5. Create a comparison DataFrame sorted by validation MSE.
# 6. Identify underfitting, possible overfitting, and the best-generalizing feature set.

# %%
# TODO 18
feature_sets = {
    "A_simple": ["size_sqft"],
    "B_multiple": ["size_sqft", "bedrooms", "age_years", "distance_city_km"],
    "C_engineered": ["size_sqft", "bedrooms", "age_years", "distance_city_km", "lot_area_sqft"],
    "D_transformed": ["size_sqft", "bedrooms", "age_years", "distance_city_km", "lot_area_sqft", "sqrt_size_sqft"],
    "E_higher_complexity": ["size_sqft", "bedrooms", "age_years", "distance_city_km", "lot_area_sqft", "sqrt_size_sqft", "size_sqft_squared"],
}
# ...

# %% [markdown]
# # 19. Interpret Your Feature Choice
#
# ### TODO 19 — Technical interpretation
#
# Write 4–8 sentences answering:
# 1. Which feature set performed best on validation data?
# 2. Which features did it include?
# 3. Did feature engineering help?
# 4. Did polynomial/transformed features help?
# 5. Did extra complexity eventually stop helping?
# 6. Which features would you keep in a first production-oriented model?
# 7. What additional real-world features might improve prediction?
# 8. Why should a regression coefficient not automatically be interpreted causally?

# %% [markdown]
# ### TODO 19 Response
#
# Write your interpretation here.

# %% [markdown]
# # 20. Final Practical Challenge
#
# ### TODO 20 — Complete end-to-end pipeline
#
# In one coherent section:
# 1. Load the CSV.
# 2. Engineer your chosen features.
# 3. Split into training and validation data.
# 4. Learn scaling parameters from the training set only.
# 5. Scale training and validation features.
# 6. Train a multiple-regression model.
# 7. Report learned parameters, training MSE, and validation MSE.
# 8. Produce a predicted-vs-actual validation plot.
# 9. If using gradient descent, also plot the learning curve.
# 10. Predict one hypothetical house that you define and label the output as a **model estimate**.
#
# **Constraint:** Do not use `sklearn.linear_model.LinearRegression` for the core fitting step.

# %%
# TODO 20
# Build your complete Week 3 pipeline here.

# %% [markdown]
# # 21. Concept Questions
#
# ### TODO 21
# Answer each in 3–6 sentences.
#
# **A. Vectorization:** Why is \($X\mathbf w+b$\) preferable to nested Python loops for large problems?
# **B. Multiple vs. multivariate regression:** What is the distinction?
# **C. Scaling:** Why can scaling improve optimization without changing the information content?
# **D. Normal equation:** Why is a direct solution attractive for moderate problems but less suitable for very large models?
# **E. Feature engineering:** Why might `frontage × depth` be more informative than either feature alone?
# **F. Polynomial features:** How can they improve fit while increasing variance?
# **G. Validation:** Why should feature selection rely on validation performance rather than training error alone?
# **H. Causality:** Why does a large regression coefficient not prove causation?

# %% [markdown]
# # 22. Submission Checklist
#
# - [ ] Loaded the dataset from the CSV file.
# - [ ] Represented examples with vectors and the full dataset with a matrix.
# - [ ] Implemented vectorized prediction.
# - [ ] Implemented the multiple-regression cost function.
# - [ ] Implemented vectorized gradients.
# - [ ] Implemented Batch Gradient Descent.
# - [ ] Updated all parameters simultaneously.
# - [ ] Compared raw and scaled features.
# - [ ] Implemented multiple scaling methods.
# - [ ] Diagnosed convergence and learning-rate behavior.
# - [ ] Solved the regression problem using least squares.
# - [ ] Engineered at least one new feature.
# - [ ] Created polynomial/transformed features.
# - [ ] Used a train/validation split.
# - [ ] Learned scaling statistics from training data only.
# - [ ] Compared several candidate feature sets.
# - [ ] Selected the final model using validation performance.
# - [ ] Interpreted the result using appropriate ML terminology.
#
# ## Week 3 Summary
#
# $$
# \boxed{\text{Raw features}\rightarrow\text{Engineering}\rightarrow\text{Scaling}\rightarrow X\mathbf w+b\rightarrow J\rightarrow\nabla J\rightarrow\text{Optimization}\rightarrow\text{Validation}\rightarrow\text{Feature choice}}
# $$
#
# A strong regression model depends not only on the optimizer, but also on how the input information is represented.
